# %%
# first program in python
print("Hello World")
print(2)

#Printing a string
print("2 + 3")

#Adding two strings
print("2" + "3")

#Adding two numbers
print("Addition is \\ \n", 2+3, "hello world")

#Hello world should be in quotes, it is string
print ("Hello world")

#Printing string and integer in same line
print("Your new score is","\n",1030+10)

#No the second argument is not integer, its string
print("Your new score is", 1030 + 10)

#No, you cant add integer and string
print (10 + int("20"))

#Data types:
'''Floating Point Numbers
   Integer Numbers
   String
   Boolean
'''

age=30
PI=3.14
std_name="Ali"
passs=True

#Determining the data type of variable using type() function
print(age,PI,std_name,passs,sep='\n')
print(type(PI))
print(type(std_name))
print((type(passs)))
print(type(age))

char = input()
print(char)

#Or cast integer to string
print (str(10) + "20")

#Get input and print
character = input("Enter any Character: ")
print (type(character))

#Input can be string i.e. a complete sentence
num = float(input("Enter sentence: "))
print (num + 5.5)


#See the type of input
print ("character is ", type(character))
print ("sentence is", type("this is sample"))

#Hello world without \n, escape sequence
print("Hello World")

#Hello world with "\n", escape sequence
print("Hello World\n")

#Many \n
print("This \t is \t my \t sample.")

# This is a comment, it begins with a # sign
# and the computer will ignore it.

print("This is not a comment, the computer will")
print("run this and print it out.")

#Multi Line Comment
print("Hi")
'''
This is
a
multi
line
comment. Nothing
Will run in between these quotes.
print("There")
'''
print("Done")

# Creating variable

# Create a variable x
# Store the value 10 into it.
x = "10"
 
# This prints the value stored in x.
print(x)
 
# This prints the letter x, but not the value in x
print("x")
 
# This prints "x= 10"
print("x =", X)
print("y =", 10)

#Case sensitive
x = 6
first1 = 5
First1 = 10
print(First1)

print(first1)

# These do not work
y = 10
x = 5*y
x = 5*(10/2)
print(x)

# These do work
y = 10
x = 5 * y
x = 5 * (3 / 2)
print(x, "this is y: ", y)

average = 90 + 86 + 71 + 100 + 98 / 5
print(average)

num1 = int(input("Enter number1: "))
num2 = int(input("Enter number2: "))

print("Integer value: ", num1//num2)
print("float value: ", num1/num2)

#By using parentheses this problem can be fixed:
average = (90 + 86 + 71 + 100 + 98.0) // 5
print(average)



# Import the math library
# This line is done only once, and at the very top
# of the program.
from math import *
 
# Calculate x using sine and cosine
x = sin(0) + cos(0)
print(x)

# Find miles per gallon
miles_driven = int(input("Enter miles driven:"))
gallons_used = int(input("Enter gallons used:"))
mpg = miles_driven // gallons_used
print("Miles per gallon:", mpg)

#Introducing float
a = 2.7
print (type(a))
print (a)

#Float to int conversion
b = int(a)
print (b)

#Binary numbers
number = int(input("Enter number to convert in Binary"))
bin_number = bin(number)
print (bin_number)

#More Binary numbers
number = 2
binary_number = bin(number)
print (binary_number)

number = 3
binary_number = bin(number)
print (binary_number)

number = 4
binary_number = bin(number)
print (binary_number)

number = 5
binary_number = bin(number)
print (binary_number)


#If statements
# Variables used in the example if statements
a = 4
b = 6
# Basic comparisons
if a < b:
    
    print("a is less than b") 
    
elif b < a:
    print("a is greater than b")
    
else:
    print("Equal")

print("Done")


#Temperature Check
#Enter 99 and 82
temperature = int(input("What is the temperature in Fahrenheit? "))
if temperature > 90:
    print("It is hot outside")
else:
    print("It is not hot outside")
print("Done")



#Temperature Check
#Enter 95, 65, 23
temperature = int(input("What is the temperature in Fahrenheit? "))
if temperature > 90:
    print("It is hot outside")
elif temperature < 30:
    print("It is cold outside")
else:
    print("It is not hot outside")
print("Done")



#String comparison
#Enter Paul and Tom
user_name = input("What is your name? ")
if user_name == "Paul":
    print("You have a nice name.")
else:
    print("Your name is ok.")
